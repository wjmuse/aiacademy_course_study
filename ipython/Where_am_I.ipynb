# %%
from __future__ import print_function
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
import pandas as pd
import numpy as np
from collections import Counter, OrderedDict

from PIL import Image as PImage
from os import listdir
from pickle import dump
import matplotlib.pyplot as plt
import PIL, cv2, os, json, glob, h5py, keras, csv
from IPython.display import SVG

import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils import to_categorical
from keras.backend.tensorflow_backend import set_session
from keras.callbacks import TensorBoard
from keras.applications.vgg16 import preprocess_input
from keras.utils.vis_utils import plot_model, model_to_dot

import seaborn as sns
# Out:
# Using TensorFlow backend.

# %%
train_path = '../data/aia-picture-classification1/train'
test_path = '../data/aia-picture-classification1/test'
model_path = '../data/aia-picture-classification1/model'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9795142609091428438
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6966991258
# locality {
#   bus_id: 1
# }
# incarnation: 17566226578062876436
# physical_device_desc: "device: 0, name: TITAN Xp, pci bus id: 0000:02:00.0, compute capability: 6.1"
# ]

# %%
label_list = !ls {train_path}
label_list
# Out:
# ['bedroom',
#  'CALsuburb',
#  'coast',
#  'forest',
#  'highway',
#  'industrial',
#  'insidecity',
#  'kitchen',
#  'livingroom',
#  'mountain',
#  'opencountry',
#  'PARoffice',
#  'store',
#  'street',
#  'tallbuilding']

# %%
mtype_dict = {}
mtype_list = [None] * len(label_list)
with open('../data/aia-picture-classification1/target_to_number.txt', newline='') as csvfile:
    _dict = csv.DictReader(csvfile)
    for idx, row in enumerate(_dict):
        mtype_dict[row['type'].strip()] = int(row[' index'].strip())
        mtype_list[int(row[' index'].strip())] = row['type'].strip()

# %%
mtype_list
# Out:
# ['kitchen',
#  'street',
#  'industrial',
#  'insidecity',
#  'forest',
#  'livingroom',
#  'opencountry',
#  'PARoffice',
#  'mountain',
#  'CALsuburb',
#  'coast',
#  'store',
#  'bedroom',
#  'tallbuilding',
#  'highway']

# %%
from keras.layers import *
from keras.optimizers import *
from keras.applications import *

from keras.preprocessing.image import img_to_array, load_img
from keras.models import Model
from keras.layers import Input, Dense, Flatten, Conv2D, Dropout, BatchNormalization
from keras import regularizers
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

# %%
img_width , img_height = 299, 299  # change based on the shape/structure of your images
nb_classes = len(mtype_dict)
batch_size = 32
nb_epoch = 100
based_model_last_block_layer_number = 126  # value is based on based model selected.

# %%
base_model = Xception(input_shape=(img_width, img_height, 3), weights='imagenet', include_top=False)

for layer in base_model.layers:
    layer.trainable = False

    
x = base_model.output
x = GlobalMaxPooling2D()(x)
x = Dropout(0.2)(x)
output = Dense(nb_classes, activation='softmax')(x)    

# add your top layer block to your base model
model = Model(base_model.input, output)
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 74, 74, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 37, 37, 256)  32768       add_1[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 37, 37, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 19, 19, 728)  186368      add_2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 19, 19, 728)  2912        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_11[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 10, 10, 1024) 745472      add_11[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 10, 10, 1024) 4096        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_12[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2048)         0           global_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 15)           30735       dropout_1[0][0]
# ==================================================================================================
# Total params: 20,892,215
# Trainable params: 30,735
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________
# None

# %%
train_datagen  = image.ImageDataGenerator(featurewise_center=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rescale=1./255,
    shear_range=0.2,
    fill_mode="nearest",
    zoom_range=0.4,
    horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(train_path,
                                                    shuffle=True,
                                                    target_size=(img_width, img_height),
                                                    batch_size=batch_size)
# Out:
# Found 2985 images belonging to 15 classes.

# %%
test_datagen = image.ImageDataGenerator(rescale=1./255,featurewise_center=True,fill_mode="nearest")

test_generator =  test_datagen.flow_from_directory(test_path, 
                                     target_size=(img_width, img_height), 
                                     batch_size=batch_size,
                                     shuffle=False,
                                     class_mode=None)
# Out:
# Found 1500 images belonging to 1 classes.

# %%
model.compile(optimizer='nadam',
              loss=categorical_crossentropy, metrics=['accuracy',])

# %%
top_weights_path = os.path.join(model_path, 'top_model_weights_6.h5')
csv_path = os.path.join(model_path, 'top_model_csv_6.h5')
callbacks_list = [
    ModelCheckpoint(top_weights_path, monitor='acc', verbose=1, save_best_only=True),
    EarlyStopping(monitor='loss', patience=10, verbose=0),
    CSVLogger(csv_path, separator=',', append=False)
]

# %%
filenames = train_generator.filenames
nb_samples = len(filenames)

print('There are {0} training data.'.format(train_generator.n))
# Out:
# There are 2985 training data.

# %%
model.fit_generator(train_generator,
                    steps_per_epoch=train_generator.n // batch_size,
                    epochs=nb_epoch / 5,
                    #validation_data=test_generator,
                    #nb_val_samples=test_generator.n,
                    callbacks=callbacks_list,
                    workers=16,
                    use_multiprocessing=True)
# Out:
# Epoch 1/20
# 93/93 [==============================] - 20s 216ms/step - loss: 2.7655 - acc: 0.3549
#
# Epoch 00001: acc improved from -inf to 0.35591, saving model to ../data/aia-picture-classification1/model/top_model_weights_6.h5
# Epoch 2/20
# 93/93 [==============================] - 18s 194ms/step - loss: 1.4061 - acc: 0.6049
#
# Epoch 00002: acc improved from 0.35591 to 0.60616, saving model to ../data/aia-picture-classification1/model/top_model_weights_6.h5
# Epoch 3/20
# 93/93 [==============================] - 19s 200ms/step - loss: 1.3371 - acc: 0.6508
#
# Epoch 00003: acc improved from 0.60616 to 0.65154, saving model to ../data/aia-picture-classification1/model/top_model_weights_6.h5
# Epoch 4/20
# 93/93 [==============================] - 18s 195ms/step - loss: 1.1967 - acc: 0.6760
#
# Epoch 00004: acc improved from 0.65154 to 0.67694, saving model to ../data/aia-picture-classification1/model/top_model_weights_6.h5
# Epoch 5/20
# 93/93 [==============================] - 19s 201ms/step - loss: 1.1066 - acc: 0.6977
#
# Epoch 00005: acc improved from 0.67694 to 0.69793, saving model to ../data/aia-picture-classification1/model/top_model_weights_6.h5
# Epoch 6/20
# 93/93 [==============================] - 19s 203ms/step - loss: 1.0753 - acc: 0.7137
#
# Epoch 00006: acc improved from 0.69793 to 0.71317, saving model to ../data/aia-picture-classification1/model/top_model_weights_6.h5
# Epoch 7/20
# 93/93 [==============================] - 19s 203ms/step - loss: 1.1516 - acc: 0.7053
#
# Epoch 00007: acc did not improve
# Epoch 8/20
# 93/93 [==============================] - 19s 202ms/step - loss: 0.9825 - acc: 0.7384
#
# Epoch 00008: acc improved from 0.71317 to 0.73891, saving model to ../data/aia-picture-classification1/model/top_model_weights_6.h5
# Epoch 9/20
# 93/93 [==============================] - 18s 198ms/step - loss: 1.1158 - acc: 0.7294
#
# Epoch 00009: acc did not improve
# Epoch 10/20
# 93/93 [==============================] - 19s 200ms/step - loss: 1.0354 - acc: 0.7333
#
# Epoch 00010: acc did not improve
# Epoch 11/20
# 93/93 [==============================] - 18s 198ms/step - loss: 0.9101 - acc: 0.7587
#
# Epoch 00011: acc improved from 0.73891 to 0.75874, saving model to ../data/aia-picture-classification1/model/top_model_weights_6.h5
# Epoch 12/20
# 93/93 [==============================] - 19s 200ms/step - loss: 0.9830 - acc: 0.7449
#
# Epoch 00012: acc did not improve
# Epoch 13/20
# 93/93 [==============================] - 19s 202ms/step - loss: 1.1262 - acc: 0.7274
#
# Epoch 00013: acc did not improve
# Epoch 14/20
# 93/93 [==============================] - 19s 199ms/step - loss: 0.9701 - acc: 0.7540
#
# Epoch 00014: acc did not improve
# Epoch 15/20
# 93/93 [==============================] - 19s 202ms/step - loss: 1.0401 - acc: 0.7367
#
# Epoch 00015: acc did not improve
# Epoch 16/20
# 93/93 [==============================] - 18s 199ms/step - loss: 1.0112 - acc: 0.7609
#
# Epoch 00016: acc improved from 0.75874 to 0.75991, saving model to ../data/aia-picture-classification1/model/top_model_weights_6.h5
# Epoch 17/20
# 93/93 [==============================] - 19s 200ms/step - loss: 0.9407 - acc: 0.7731
#
# Epoch 00017: acc improved from 0.75991 to 0.77311, saving model to ../data/aia-picture-classification1/model/top_model_weights_6.h5
# Epoch 18/20
# 93/93 [==============================] - 18s 194ms/step - loss: 0.9296 - acc: 0.7716
#
# Epoch 00018: acc did not improve
# Epoch 19/20
# 93/93 [==============================] - 19s 199ms/step - loss: 1.0053 - acc: 0.7582
#
# Epoch 00019: acc did not improve
# Epoch 20/20
# 93/93 [==============================] - 18s 198ms/step - loss: 0.9784 - acc: 0.7620
#
# Epoch 00020: acc did not improve

# %%
model.load_weights(top_weights_path)

# %%
for layer in model.layers[:based_model_last_block_layer_number]:
    layer.trainable = False
for layer in model.layers[based_model_last_block_layer_number:]:
    layer.trainable = True

# %%
model.compile(optimizer='nadam',
              loss=categorical_crossentropy, metrics=['accuracy',])

# %%
final_weights_path = os.path.join(model_path, 'model_weights_v5.h5')
csv_path = os.path.join(model_path, 'model_csv_v5.csv')
callbacks_list = [
    ModelCheckpoint(final_weights_path, monitor='acc', verbose=1, save_best_only=True),
    EarlyStopping(monitor='loss', patience=20, verbose=0),
    CSVLogger(csv_path, separator=',', append=False)
]

# %%
# fine-tune the model
model.fit_generator(train_generator,
                    steps_per_epoch=train_generator.n // batch_size,
                    epochs=nb_epoch,
                    callbacks=callbacks_list,
                    workers=16,
                    use_multiprocessing=True)


# save model
model_json = model.to_json()
with open(os.path.join(model_path, 'model_v5.json'), 'w') as json_file:
    json_file.write(model_json)
# Out:
# Epoch 1/100
# 93/93 [==============================] - 20s 219ms/step - loss: 0.9189 - acc: 0.7807
#
# Epoch 00001: acc improved from -inf to 0.78158, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 2/100
#
# 93/93 [==============================] - 19s 208ms/step - loss: 0.4040 - acc: 0.8704
#
# Epoch 00002: acc improved from 0.78158 to 0.87030, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 3/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.3407 - acc: 0.8876
#
# Epoch 00003: acc improved from 0.87030 to 0.88927, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 4/100
# 93/93 [==============================] - 20s 213ms/step - loss: 0.2852 - acc: 0.9040
#
# Epoch 00004: acc improved from 0.88927 to 0.90417, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 5/100
# 93/93 [==============================] - 20s 210ms/step - loss: 0.2681 - acc: 0.9066
#
# Epoch 00005: acc improved from 0.90417 to 0.90586, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 6/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.2320 - acc: 0.9247
#
# Epoch 00006: acc improved from 0.90586 to 0.92414, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 7/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.2153 - acc: 0.9284
#
# Epoch 00007: acc improved from 0.92414 to 0.92787, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 8/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.2264 - acc: 0.9247
#
# Epoch 00008: acc did not improve
# Epoch 9/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.1842 - acc: 0.9415
#
# Epoch 00009: acc improved from 0.92787 to 0.94108, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 10/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.1585 - acc: 0.9487
#
# Epoch 00010: acc improved from 0.94108 to 0.94920, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 11/100
# 93/93 [==============================] - 20s 212ms/step - loss: 0.1674 - acc: 0.9432
#
# Epoch 00011: acc did not improve
# Epoch 12/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.1814 - acc: 0.9383
#
# Epoch 00012: acc did not improve
# Epoch 13/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.1750 - acc: 0.9425
#
# Epoch 00013: acc did not improve
# Epoch 14/100
# 93/93 [==============================] - 19s 205ms/step - loss: 0.1320 - acc: 0.9545
#
# Epoch 00014: acc improved from 0.94920 to 0.95496, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 15/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.1259 - acc: 0.9570
#
# Epoch 00015: acc improved from 0.95496 to 0.95665, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 16/100
# 93/93 [==============================] - 20s 213ms/step - loss: 0.1340 - acc: 0.9529
#
# Epoch 00016: acc did not improve
# Epoch 17/100
# 93/93 [==============================] - 20s 216ms/step - loss: 0.1336 - acc: 0.9536
#
# Epoch 00017: acc did not improve
# Epoch 18/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.1365 - acc: 0.9534
#
# Epoch 00018: acc did not improve
# Epoch 19/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.1168 - acc: 0.9622
#
# Epoch 00019: acc improved from 0.95665 to 0.96275, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 20/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.1182 - acc: 0.9571
#
# Epoch 00020: acc did not improve
# Epoch 21/100
# 93/93 [==============================] - 20s 210ms/step - loss: 0.1197 - acc: 0.9597
#
# Epoch 00021: acc did not improve
# Epoch 22/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.1078 - acc: 0.9666
#
# Epoch 00022: acc improved from 0.96275 to 0.96715, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 23/100
# 93/93 [==============================] - 20s 214ms/step - loss: 0.1387 - acc: 0.9539
#
# Epoch 00023: acc did not improve
# Epoch 24/100
# 93/93 [==============================] - 20s 212ms/step - loss: 0.0951 - acc: 0.9676
#
# Epoch 00024: acc improved from 0.96715 to 0.96817, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 25/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0955 - acc: 0.9674
#
# Epoch 00025: acc did not improve
# Epoch 26/100
# 93/93 [==============================] - 20s 212ms/step - loss: 0.0949 - acc: 0.9681
#
# Epoch 00026: acc did not improve
# Epoch 27/100
# 93/93 [==============================] - 20s 210ms/step - loss: 0.0917 - acc: 0.9694
#
# Epoch 00027: acc improved from 0.96817 to 0.96894, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 28/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0938 - acc: 0.9718
#
# Epoch 00028: acc improved from 0.96894 to 0.97155, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 29/100
# 93/93 [==============================] - 20s 212ms/step - loss: 0.0973 - acc: 0.9644
#
# Epoch 00029: acc did not improve
# Epoch 30/100
# 93/93 [==============================] - 20s 213ms/step - loss: 0.1081 - acc: 0.9603
#
# Epoch 00030: acc did not improve
# Epoch 31/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.1077 - acc: 0.9634
#
# Epoch 00031: acc did not improve
# Epoch 32/100
# 93/93 [==============================] - 19s 210ms/step - loss: 0.1107 - acc: 0.9647
#
# Epoch 00032: acc did not improve
# Epoch 33/100
# 93/93 [==============================] - 20s 214ms/step - loss: 0.1136 - acc: 0.9615
#
# Epoch 00033: acc did not improve
# Epoch 34/100
# 93/93 [==============================] - 19s 206ms/step - loss: 0.1042 - acc: 0.9681
#
# Epoch 00034: acc did not improve
# Epoch 35/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0906 - acc: 0.9676
#
# Epoch 00035: acc did not improve
# Epoch 36/100
# 93/93 [==============================] - 19s 210ms/step - loss: 0.0934 - acc: 0.9664
#
# Epoch 00036: acc did not improve
# Epoch 37/100
# 93/93 [==============================] - 19s 206ms/step - loss: 0.0765 - acc: 0.9775
#
# Epoch 00037: acc improved from 0.97155 to 0.97713, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 38/100
# 93/93 [==============================] - 19s 203ms/step - loss: 0.0831 - acc: 0.9770
#
# Epoch 00038: acc improved from 0.97713 to 0.97765, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 39/100
# 93/93 [==============================] - 20s 212ms/step - loss: 0.0930 - acc: 0.9651
#
# Epoch 00039: acc did not improve
# Epoch 40/100
# 93/93 [==============================] - 19s 206ms/step - loss: 0.0903 - acc: 0.9723
#
# Epoch 00040: acc did not improve
# Epoch 41/100
# 93/93 [==============================] - 20s 213ms/step - loss: 0.0926 - acc: 0.9708
#
# Epoch 00041: acc did not improve
# Epoch 42/100
# 93/93 [==============================] - 19s 204ms/step - loss: 0.1066 - acc: 0.9647
#
# Epoch 00042: acc did not improve
# Epoch 43/100
# 93/93 [==============================] - 19s 205ms/step - loss: 0.0851 - acc: 0.9738
#
# Epoch 00043: acc did not improve
# Epoch 44/100
# 93/93 [==============================] - 19s 207ms/step - loss: 0.0728 - acc: 0.9731
#
# Epoch 00044: acc did not improve
# Epoch 45/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0890 - acc: 0.9735 - ETA: 4s - loss
#
# Epoch 00045: acc did not improve
# Epoch 46/100
# 93/93 [==============================] - 19s 206ms/step - loss: 0.0742 - acc: 0.9739
#
# Epoch 00046: acc did not improve
# Epoch 47/100
# 93/93 [==============================] - 20s 214ms/step - loss: 0.0905 - acc: 0.9738
#
# Epoch 00047: acc did not improve
# Epoch 48/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0873 - acc: 0.9721
#
# Epoch 00048: acc did not improve
# Epoch 49/100
# 93/93 [==============================] - 20s 213ms/step - loss: 0.0938 - acc: 0.9704
#
# Epoch 00049: acc did not improve
# Epoch 50/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0633 - acc: 0.9812
#
# Epoch 00050: acc improved from 0.97765 to 0.98118, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 51/100
# 93/93 [==============================] - 20s 213ms/step - loss: 0.0779 - acc: 0.9768
#
# Epoch 00051: acc did not improve
# Epoch 52/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0751 - acc: 0.9744
#
# Epoch 00052: acc did not improve
# Epoch 53/100
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0670 - acc: 0.9815
#
# Epoch 00053: acc improved from 0.98118 to 0.98152, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 54/100
# 93/93 [==============================] - 20s 212ms/step - loss: 0.0641 - acc: 0.9795
#
# Epoch 00054: acc did not improve
# Epoch 55/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0731 - acc: 0.9772
#
# Epoch 00055: acc did not improve
# Epoch 56/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0724 - acc: 0.9775
#
# Epoch 00056: acc did not improve
# Epoch 57/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0666 - acc: 0.9770
#
# Epoch 00057: acc did not improve
# Epoch 58/100
# 93/93 [==============================] - 20s 213ms/step - loss: 0.0754 - acc: 0.9773
#
# Epoch 00058: acc did not improve
# Epoch 59/100
# 93/93 [==============================] - 20s 214ms/step - loss: 0.0605 - acc: 0.9802
#
# Epoch 00059: acc did not improve
# Epoch 60/100
# 93/93 [==============================] - 19s 203ms/step - loss: 0.0662 - acc: 0.9775
#
# Epoch 00060: acc did not improve
# Epoch 61/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0699 - acc: 0.9785
#
# Epoch 00061: acc did not improve
# Epoch 62/100
# 93/93 [==============================] - 20s 210ms/step - loss: 0.0563 - acc: 0.9849
#
# Epoch 00062: acc improved from 0.98152 to 0.98488, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 63/100
# 93/93 [==============================] - 20s 210ms/step - loss: 0.0470 - acc: 0.9872
#
# Epoch 00063: acc improved from 0.98488 to 0.98703, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 64/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0570 - acc: 0.9802
#
# Epoch 00064: acc did not improve
# Epoch 65/100
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0628 - acc: 0.9842
#
# Epoch 00065: acc did not improve
# Epoch 66/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0628 - acc: 0.9812
#
# Epoch 00066: acc did not improve
# Epoch 67/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0511 - acc: 0.9839
#
# Epoch 00067: acc did not improve
# Epoch 68/100
# 93/93 [==============================] - 19s 207ms/step - loss: 0.0733 - acc: 0.9765
#
# Epoch 00068: acc did not improve
# Epoch 69/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0541 - acc: 0.9849
#
# Epoch 00069: acc did not improve
# Epoch 70/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0794 - acc: 0.9785
#
# Epoch 00070: acc did not improve
# Epoch 71/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0594 - acc: 0.9813
#
# Epoch 00071: acc did not improve
# Epoch 72/100
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0658 - acc: 0.9785
#
# Epoch 00072: acc did not improve
# Epoch 73/100
# 93/93 [==============================] - 20s 214ms/step - loss: 0.0672 - acc: 0.9761
#
# Epoch 00073: acc did not improve
# Epoch 74/100
# 93/93 [==============================] - 19s 207ms/step - loss: 0.0554 - acc: 0.9825
#
# Epoch 00074: acc did not improve
# Epoch 75/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0509 - acc: 0.9829
#
# Epoch 00075: acc did not improve
# Epoch 76/100
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0455 - acc: 0.9832
#
# Epoch 00076: acc did not improve
# Epoch 77/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0546 - acc: 0.9842
#
# Epoch 00077: acc did not improve
# Epoch 78/100
# 93/93 [==============================] - 19s 203ms/step - loss: 0.0591 - acc: 0.9808
#
# Epoch 00078: acc did not improve
# Epoch 79/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0471 - acc: 0.9842
#
# Epoch 00079: acc did not improve
# Epoch 80/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0547 - acc: 0.9839
#
# Epoch 00080: acc did not improve
# Epoch 81/100
# 93/93 [==============================] - 19s 206ms/step - loss: 0.0497 - acc: 0.9842
#
# Epoch 00081: acc did not improve
# Epoch 82/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0613 - acc: 0.9812
#
# Epoch 00082: acc did not improve
# Epoch 83/100
# 93/93 [==============================] - 20s 213ms/step - loss: 0.0641 - acc: 0.9788
#
# Epoch 00083: acc did not improve
# Epoch 84/100
# 93/93 [==============================] - 20s 212ms/step - loss: 0.0545 - acc: 0.9835
#
# Epoch 00084: acc did not improve
# Epoch 85/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0403 - acc: 0.9855
#
# Epoch 00085: acc did not improve
# Epoch 86/100
# 93/93 [==============================] - 19s 207ms/step - loss: 0.0513 - acc: 0.9842
#
# Epoch 00086: acc did not improve
# Epoch 87/100
# 93/93 [==============================] - 20s 212ms/step - loss: 0.0394 - acc: 0.9859
#
# Epoch 00087: acc did not improve
# Epoch 88/100
# 93/93 [==============================] - 19s 208ms/step - loss: 0.0568 - acc: 0.9802
#
# Epoch 00088: acc did not improve
# Epoch 89/100
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0418 - acc: 0.9866
#
# Epoch 00089: acc did not improve
# Epoch 90/100
# 93/93 [==============================] - 20s 214ms/step - loss: 0.0438 - acc: 0.9845
#
# Epoch 00090: acc did not improve
# Epoch 91/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0529 - acc: 0.9862
#
# Epoch 00091: acc did not improve
# Epoch 92/100
# 93/93 [==============================] - 19s 209ms/step - loss: 0.0471 - acc: 0.9866
#
# Epoch 00092: acc did not improve
# Epoch 93/100
# 93/93 [==============================] - 20s 212ms/step - loss: 0.0493 - acc: 0.9842
#
# Epoch 00093: acc did not improve
# Epoch 94/100
# 93/93 [==============================] - 18s 191ms/step - loss: 0.0531 - acc: 0.9852
#
# Epoch 00094: acc did not improve
# Epoch 95/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0391 - acc: 0.9896
#
# Epoch 00095: acc improved from 0.98703 to 0.98950, saving model to ../data/aia-picture-classification1/model/model_weights_v5.h5
# Epoch 96/100
#
# Epoch 00094: acc did not improve
# Epoch 95/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0543 - acc: 0.9834
#
# Epoch 00096: acc did not improve
# Epoch 97/100
# 93/93 [==============================] - 19s 201ms/step - loss: 0.0582 - acc: 0.9808
#
# Epoch 00097: acc did not improve
# Epoch 98/100
# 93/93 [==============================] - 19s 207ms/step - loss: 0.0498 - acc: 0.9837
#
# Epoch 00098: acc did not improve
# Epoch 99/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0484 - acc: 0.9813
#
# Epoch 00099: acc did not improve
# Epoch 100/100
# 93/93 [==============================] - 20s 211ms/step - loss: 0.0503 - acc: 0.9842
#
# Epoch 00100: acc did not improve

# %%
model.load_weights(final_weights_path)

# %%
X_l_vec = model.predict_generator(generator=test_generator)

# %%
predict_index = np.argmax(X_l_vec, axis=-1)

# %%
fnames = [_f.split('/')[1].replace('.jpg','') for _f in test_generator.filenames]

# %%
predict_index
# Out:
# array([ 1,  4,  4, ..., 10, 11, 13])

# %%
fnames[0]
# Out:
# '001d4c8d70ebf7f025fccf256324d3d5ad3560faee1cdf8c7115f5eb033bc3d2'

# %%
class_list = [None] * len(train_generator.class_indices)
for _item in train_generator.class_indices:
    class_list[train_generator.class_indices[_item]] = _item

# %%
train_generator.class_indices
# Out:
# {'CALsuburb': 0,
#  'PARoffice': 1,
#  'bedroom': 2,
#  'coast': 3,
#  'forest': 4,
#  'highway': 5,
#  'industrial': 6,
#  'insidecity': 7,
#  'kitchen': 8,
#  'livingroom': 9,
#  'mountain': 10,
#  'opencountry': 11,
#  'store': 12,
#  'street': 13,
#  'tallbuilding': 14}

# %%
predict_index.shape
# Out:
# (1500,)

# %%
mtype_dict
# Out:
# {'CALsuburb': 9,
#  'PARoffice': 7,
#  'bedroom': 12,
#  'coast': 10,
#  'forest': 4,
#  'highway': 14,
#  'industrial': 2,
#  'insidecity': 3,
#  'kitchen': 0,
#  'livingroom': 5,
#  'mountain': 8,
#  'opencountry': 6,
#  'store': 11,
#  'street': 1,
#  'tallbuilding': 13}

# %%
cateidxs = [mtype_dict[class_list[_p]] for _p in predict_index]

# %%
percentile_list = pd.DataFrame(
    {'id': fnames,
     'class': cateidxs
    })

# %%
percentile_list.to_csv('out_5.csv',encoding='utf-8', index=False,columns=["id","class"])
